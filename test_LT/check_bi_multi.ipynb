# %%
import pandas as pd

# %%
df = pd.read_excel(r"\\main.oecd.org\ASgenDCD\DEVELOPMENT_AID\__PROCESSING\checklist_r\2_functions\test_crstemplate_LT.xlsx",header = 1)
df = df.loc[1:].reset_index(drop=True)
df["error_message"] = ""
df["warning_message"] = ""

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df.head()  # Display the first few rows of the DataFrame

# %% [markdown]
# #### errormessage : Invalid entry for Bi/Multi, please enter a value of 1, 2, 3, 4, 6, 7, or 8

# %%
df.loc[((df["Type of flow (main DAC 1 category)"]== 10) |
        (df["Type of flow (main DAC 1 category)"]== 21 ) | 
          (df["Type of flow (main DAC 1 category)"]== 60 )) &
            ((df["Bi/Multi"]!=1) &
             (df["Bi/Multi"]!=2) &
             (df["Bi/Multi"]!=3) &
             (df["Bi/Multi"]!=4) &
             (df["Bi/Multi"]!=6) &
             (df["Bi/Multi"]!=7) &
              (df["Bi/Multi"]!=8))]
# Out:
#     Reporting year Commitment date (dd-mm-yyyy)  Reporting country / organisation  Extending agency  CRS Identification N° Donor project N°  Nature of submission  Recipient code  Channel of delivery name  Channel code  Bi/Multi  Type of flow (main DAC 1 category)  Type of finance Co-operation modality (replaces the type of aid)        Short description / Project title Sector / Purpose code and corresponding shares   Geographical target area  Regional aid to LDCs (codes 1-5)  Expected starting date   Expected completion date                                        Description SDG focus*  Keywords*  Gender equality  Aid to environment  DIG  RMNCH  Disaster Risk Reduction  Nutrition*  Inclusion and empowerment of persons with disabilities*  FTC  PBA  Investment  Type of blended finance (codes 1-4)   Biodiversity  Climate change - mitigation  Climate change - adaptation  Desertification  Currency  Commitments  Capital Expenditure %*  Amounts extended  ODA grant equivalent  \
# ...

# %%
df.loc[((df["Type of flow (main DAC 1 category)"]== 10) |
        (df["Type of flow (main DAC 1 category)"]== 21 ) | 
          (df["Type of flow (main DAC 1 category)"]== 60 )) &
            ((df["Bi/Multi"]!=1) &
             (df["Bi/Multi"]!=2) &
             (df["Bi/Multi"]!=3) &
             (df["Bi/Multi"]!=4) &
             (df["Bi/Multi"]!=6) &
             (df["Bi/Multi"]!=7) &
              (df["Bi/Multi"]!=8)), "error_message"] = df["error_message"] + " ;Invalid entry for Bi/Multi, please enter a value of 1, 2, 3, 4, 6, 7, or 8"

# %%
df[["Type of flow (main DAC 1 category)", "Bi/Multi", "error_message"]].head(20)

# %% [markdown]
# #### errormessage : Flows from countries must be reported as Bi/Multi = 1, 2, 3, 7 or 8, and these values cannot be assigned to any other flows;

# %%
# import donor_countries

# %% [markdown]
# #### errormessage : This channel is not compatible with Bi/Multi = 2, as it is not on the DAC list of ODA-eligible international organisations;

# %%
# import annex2_lookup

# %% [markdown]
# #### errormessage : If Bi/Multi = 2, recipient code should = 3000 or 998, purpose code should = 99810 and channel should be in parent channel category 40000;

# %%
df.loc[((df["Type of flow (main DAC 1 category)"]== 10) |
        (df["Type of flow (main DAC 1 category)"]== 21 ) | 
          (df["Type of flow (main DAC 1 category)"]== 60 )) &
             (df["Bi/Multi"]==2) &
             ((df["Recipient code"]!= 3000) | (df["Recipient code"]!= 998) ) &
             ((df["Sector / Purpose code and corresponding shares"].astype(str).str.contains("99810", na=False)) | 
              (df["Sector / Purpose code and corresponding shares"].astype(str).str.contains("99810:100", na=False))) &
              (df["Channel code"].astype(str).str[:1]!="4"), "error_message"] = " ;If Bi/Multi = 2, recipient code should = 3000 or 998, purpose code should = 99810 and channel should be in parent channel category 40000"

# %% [markdown]
# #### errormessage : If Bi/Multi = 3, channel must be in parent channel category 20000, 30000 or 51000;

# %% [markdown]
# #### errormessage : Outflows from multilaterals must be reported as Bi/Multi = 4, and this value cannot be assigned to any other flows;

# %%
# import multilateral_donors

# %% [markdown]
# #### errormessage : Philanthropic flows must be reported with DAC1 category = 30 and Bi/Multi = 6, and these values cannot be assigned to any other flows;

# %%
# import private_donors
