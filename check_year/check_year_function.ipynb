# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_excel(r"C:\Users\Lessard_M\Documents\Python\tor_fileuploader\data source\test_crstemplate_GG.xlsx",header = 1)
df = df.loc[1:].reset_index(drop=True)

# %%
df["Commitment date (dd-mm-yyyy)"] = df["Commitment date (dd-mm-yyyy)"].astype(str) 

df["Commitment date (dd-mm-yyyy)"] = pd.to_datetime(df["Commitment date (dd-mm-yyyy)"],format = "%d-%m-%Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 df["Commitment date (dd-mm-yyyy)"] = df["Commitment date (dd-mm-yyyy)"].astype(str)
# ----> 3 df["Commitment date (dd-mm-yyyy)"] = pd.to_datetime(df["Commitment date (dd-mm-yyyy)"],format = "%d-%m-%Y")
#
# File c:\Users\Lessard_M\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df.head()
# Out:
#    Reporting year Commitment date (dd-mm-yyyy)  \
# 0            2024                   2022-01-15
# 1            2024                   2024-01-15
# 2            2024                   2021-12-31
# 3            2024                   2024-01-01
# 4            2024                   2024-01-01
#
#    Reporting country / organisation  Extending agency  CRS Identification N°  \
# 0                                 1                 1            20220000001
# 1                                 1                 1            20220000002
# 2                                 1                 1            20220000003
# 3                                 1                 1            20220000004
# 4                              7000                 1            20220000005
#
#   Donor project N°  Nature of submission  Recipient code  \
# 0             abcd                     1             998
# 1             abcd                     1             249
# ...
